# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 759

# %%
# Import the dependencies.
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library 
import time

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_descp = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_descp,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | esperance
# Processing Record 2 of Set 1 | isangel
# Processing Record 3 of Set 1 | pisco
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | port lincoln
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | carnarvon
# Processing Record 8 of Set 1 | kodiak
# Processing Record 9 of Set 1 | vardo
# Processing Record 10 of Set 1 | pangkalanbuun
# Processing Record 11 of Set 1 | muscle shoals
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | pangnirtung
# Processing Record 16 of Set 1 | corozal
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | khatanga
# Processing Record 19 of Set 1 | anuradhapura
# Processing Record 20 of Set 1 | tulsipur
# Processing Record 21 of Set 1 | killybegs
# Processing Record 22 of Set 1 | los llanos de aridane
# Processing Record 23 of Set 1 | galle
# Processing Record 24 of Set 1 | tasiilaq
# Processing Record 25 of Set 1 | guiglo
# Processing Record 26 of Set 1 | port alfred
# Processing Record 27 of Set 1 | jinji
# Processing Record 28 of Set 1 | victoria
# Processing Record 29 of Set 1 | busselton
# Processing Record 30 of Set 1 | ostrovnoy
# Processing Record 31 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 1 | matagami
# Processing Record 33 of Set 1 | saint-philippe
# Processing Record 34 of Set 1 | vestmannaeyjar
# Processing Record 35 of Set 1 | norman wells
# Processing Record 36 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 1 | tura
# Processing Record 38 of Set 1 | tuatapere
# Processing Record 39 of Set 1 | longyearbyen
# Processing Record 40 of Set 1 | saint-augustin
# Processing Record 41 of Set 1 | ndende
# Processing Record 42 of Set 1 | utiroa
# City not found. Skipping...
# Processing Record 43 of Set 1 | boguchany
# Processing Record 44 of Set 1 | bhainsa
# Processing Record 45 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 1 | muzhi
# Processing Record 47 of Set 1 | castro
# Processing Record 48 of Set 1 | maarianhamina
# Processing Record 49 of Set 1 | rafaela
# Processing Record 50 of Set 1 | barrow
# Processing Record 1 of Set 2 | ulladulla
# Processing Record 2 of Set 2 | lorengau
# Processing Record 3 of Set 2 | cabo san lucas
# Processing Record 4 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 2 | tashla
# Processing Record 6 of Set 2 | verkhoyansk
# Processing Record 7 of Set 2 | fukue
# Processing Record 8 of Set 2 | salalah
# Processing Record 9 of Set 2 | upernavik
# Processing Record 10 of Set 2 | atuona
# Processing Record 11 of Set 2 | hammerfest
# Processing Record 12 of Set 2 | colac
# Processing Record 13 of Set 2 | sao filipe
# Processing Record 14 of Set 2 | cape town
# Processing Record 15 of Set 2 | hithadhoo
# Processing Record 16 of Set 2 | burica
# City not found. Skipping...
# Processing Record 17 of Set 2 | puerto ayora
# Processing Record 18 of Set 2 | qaanaaq
# Processing Record 19 of Set 2 | north platte
# Processing Record 20 of Set 2 | mar del plata
# Processing Record 21 of Set 2 | ribeira grande
# Processing Record 22 of Set 2 | georgetown
# Processing Record 23 of Set 2 | kruisfontein
# Processing Record 24 of Set 2 | kaitangata
# Processing Record 25 of Set 2 | hambantota
# Processing Record 26 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 2 | talnakh
# Processing Record 28 of Set 2 | kapaa
# Processing Record 29 of Set 2 | haines junction
# Processing Record 30 of Set 2 | ilulissat
# Processing Record 31 of Set 2 | tavda
# Processing Record 32 of Set 2 | hobart
# Processing Record 33 of Set 2 | ahipara
# Processing Record 34 of Set 2 | pevek
# Processing Record 35 of Set 2 | bengkulu
# Processing Record 36 of Set 2 | cherskiy
# Processing Record 37 of Set 2 | mantua
# Processing Record 38 of Set 2 | zhigansk
# Processing Record 39 of Set 2 | severo-kurilsk
# Processing Record 40 of Set 2 | butaritari
# Processing Record 41 of Set 2 | albany
# Processing Record 42 of Set 2 | aketi
# Processing Record 43 of Set 2 | ushtobe
# Processing Record 44 of Set 2 | luau
# Processing Record 45 of Set 2 | tuktoyaktuk
# Processing Record 46 of Set 2 | palafrugell
# Processing Record 47 of Set 2 | ketchikan
# Processing Record 48 of Set 2 | namibe
# Processing Record 49 of Set 2 | chuy
# Processing Record 50 of Set 2 | baykit
# Processing Record 1 of Set 3 | sur
# Processing Record 2 of Set 3 | jamestown
# Processing Record 3 of Set 3 | finschhafen
# Processing Record 4 of Set 3 | kahului
# Processing Record 5 of Set 3 | dongsheng
# Processing Record 6 of Set 3 | tahta
# Processing Record 7 of Set 3 | saskylakh
# Processing Record 8 of Set 3 | new norfolk
# Processing Record 9 of Set 3 | mahajanga
# Processing Record 10 of Set 3 | yakima
# Processing Record 11 of Set 3 | bredasdorp
# Processing Record 12 of Set 3 | porto novo
# Processing Record 13 of Set 3 | bluff
# Processing Record 14 of Set 3 | panaba
# Processing Record 15 of Set 3 | kachikau
# City not found. Skipping...
# Processing Record 16 of Set 3 | launceston
# Processing Record 17 of Set 3 | gat
# Processing Record 18 of Set 3 | faya
# Processing Record 19 of Set 3 | mulanje
# Processing Record 20 of Set 3 | arraial do cabo
# Processing Record 21 of Set 3 | vaini
# Processing Record 22 of Set 3 | boyolangu
# Processing Record 23 of Set 3 | nome
# Processing Record 24 of Set 3 | manoel urbano
# Processing Record 25 of Set 3 | dikson
# Processing Record 26 of Set 3 | lucapa
# Processing Record 27 of Set 3 | hilo
# Processing Record 28 of Set 3 | shu
# Processing Record 29 of Set 3 | dingle
# Processing Record 30 of Set 3 | tessalit
# Processing Record 31 of Set 3 | grevena
# Processing Record 32 of Set 3 | asau
# Processing Record 33 of Set 3 | santiago de cuba
# Processing Record 34 of Set 3 | lucenec
# Processing Record 35 of Set 3 | port-gentil
# Processing Record 36 of Set 3 | airai
# Processing Record 37 of Set 3 | ligayan
# Processing Record 38 of Set 3 | caravelas
# Processing Record 39 of Set 3 | aquiraz
# Processing Record 40 of Set 3 | codrington
# Processing Record 41 of Set 3 | xai-xai
# Processing Record 42 of Set 3 | novikovo
# Processing Record 43 of Set 3 | east london
# Processing Record 44 of Set 3 | gari
# Processing Record 45 of Set 3 | tazovskiy
# Processing Record 46 of Set 3 | saint-leu
# Processing Record 47 of Set 3 | pabna
# Processing Record 48 of Set 3 | gurupi
# Processing Record 49 of Set 3 | rocha
# Processing Record 50 of Set 3 | constitucion
# Processing Record 1 of Set 4 | oussouye
# Processing Record 2 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 4 | deputatskiy
# Processing Record 4 of Set 4 | hamilton
# Processing Record 5 of Set 4 | eureka
# Processing Record 6 of Set 4 | qasigiannguit
# Processing Record 7 of Set 4 | fortuna
# Processing Record 8 of Set 4 | port elizabeth
# Processing Record 9 of Set 4 | iraray
# Processing Record 10 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 11 of Set 4 | tiarei
# Processing Record 12 of Set 4 | tupik
# Processing Record 13 of Set 4 | mahebourg
# Processing Record 14 of Set 4 | nanortalik
# Processing Record 15 of Set 4 | tiksi
# Processing Record 16 of Set 4 | ust-charyshskaya pristan
# Processing Record 17 of Set 4 | sal rei
# Processing Record 18 of Set 4 | avarua
# Processing Record 19 of Set 4 | kiruna
# Processing Record 20 of Set 4 | lar
# Processing Record 21 of Set 4 | husavik
# Processing Record 22 of Set 4 | jackson
# Processing Record 23 of Set 4 | namatanai
# Processing Record 24 of Set 4 | ponta do sol
# Processing Record 25 of Set 4 | sinnamary
# Processing Record 26 of Set 4 | provideniya
# Processing Record 27 of Set 4 | dormidontovka
# Processing Record 28 of Set 4 | yellowknife
# Processing Record 29 of Set 4 | chalon-sur-saone
# Processing Record 30 of Set 4 | vaitape
# Processing Record 31 of Set 4 | clyde river
# Processing Record 32 of Set 4 | vila velha
# Processing Record 33 of Set 4 | iturama
# Processing Record 34 of Set 4 | hasaki
# Processing Record 35 of Set 4 | pilao arcado
# City not found. Skipping...
# Processing Record 36 of Set 4 | cedartown
# Processing Record 37 of Set 4 | paris
# Processing Record 38 of Set 4 | tutoia
# Processing Record 39 of Set 4 | charters towers
# Processing Record 40 of Set 4 | cockburn town
# Processing Record 41 of Set 4 | meulaboh
# Processing Record 42 of Set 4 | sibolga
# Processing Record 43 of Set 4 | ballina
# Processing Record 44 of Set 4 | mitchell
# Processing Record 45 of Set 4 | torbay
# Processing Record 46 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 4 | chokurdakh
# Processing Record 49 of Set 4 | comodoro rivadavia
# Processing Record 50 of Set 4 | oranjemund
# Processing Record 1 of Set 5 | kerman
# Processing Record 2 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 5 | kieta
# Processing Record 4 of Set 5 | fez
# Processing Record 5 of Set 5 | faanui
# Processing Record 6 of Set 5 | bubaque
# Processing Record 7 of Set 5 | zhezkazgan
# Processing Record 8 of Set 5 | mosta
# Processing Record 9 of Set 5 | aklavik
# Processing Record 10 of Set 5 | el alto
# Processing Record 11 of Set 5 | port hedland
# Processing Record 12 of Set 5 | amlagora
# Processing Record 13 of Set 5 | olenino
# Processing Record 14 of Set 5 | klaksvik
# Processing Record 15 of Set 5 | khalkhal
# Processing Record 16 of Set 5 | chapada dos guimaraes
# Processing Record 17 of Set 5 | cordoba
# Processing Record 18 of Set 5 | westport
# Processing Record 19 of Set 5 | agadez
# Processing Record 20 of Set 5 | alofi
# Processing Record 21 of Set 5 | bethel
# Processing Record 22 of Set 5 | maceio
# Processing Record 23 of Set 5 | pesqueria
# Processing Record 24 of Set 5 | mossendjo
# Processing Record 25 of Set 5 | rawson
# Processing Record 26 of Set 5 | sitka
# Processing Record 27 of Set 5 | kamaishi
# Processing Record 28 of Set 5 | geraldton
# Processing Record 29 of Set 5 | katsuura
# Processing Record 30 of Set 5 | korla
# Processing Record 31 of Set 5 | sabang
# Processing Record 32 of Set 5 | karasburg
# Processing Record 33 of Set 5 | suluq
# Processing Record 34 of Set 5 | gaffney
# Processing Record 35 of Set 5 | santiago
# Processing Record 36 of Set 5 | aykhal
# Processing Record 37 of Set 5 | keighley
# Processing Record 38 of Set 5 | pangoa
# Processing Record 39 of Set 5 | sarakhs
# Processing Record 40 of Set 5 | abeche
# Processing Record 41 of Set 5 | yerbogachen
# Processing Record 42 of Set 5 | pascagoula
# Processing Record 43 of Set 5 | haradok
# Processing Record 44 of Set 5 | mount gambier
# Processing Record 45 of Set 5 | palmer
# Processing Record 46 of Set 5 | bemidji
# Processing Record 47 of Set 5 | hailar
# Processing Record 48 of Set 5 | muros
# Processing Record 49 of Set 5 | sisimiut
# Processing Record 50 of Set 5 | ghatal
# Processing Record 1 of Set 6 | sambava
# Processing Record 2 of Set 6 | panzhihua
# Processing Record 3 of Set 6 | tadine
# Processing Record 4 of Set 6 | nikolskoye
# Processing Record 5 of Set 6 | guerrero negro
# Processing Record 6 of Set 6 | kisangani
# Processing Record 7 of Set 6 | thompson
# Processing Record 8 of Set 6 | cidreira
# Processing Record 9 of Set 6 | la paz
# Processing Record 10 of Set 6 | rio gallegos
# Processing Record 11 of Set 6 | metro
# Processing Record 12 of Set 6 | te anau
# Processing Record 13 of Set 6 | chontalpa
# Processing Record 14 of Set 6 | belmonte
# Processing Record 15 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 16 of Set 6 | kvarkeno
# Processing Record 17 of Set 6 | kloulklubed
# Processing Record 18 of Set 6 | peruibe
# Processing Record 19 of Set 6 | kavaratti
# Processing Record 20 of Set 6 | seymchan
# Processing Record 21 of Set 6 | roald
# Processing Record 22 of Set 6 | grande prairie
# Processing Record 23 of Set 6 | lebu
# Processing Record 24 of Set 6 | bilma
# Processing Record 25 of Set 6 | scicli
# Processing Record 26 of Set 6 | morristown
# Processing Record 27 of Set 6 | dauphin
# Processing Record 28 of Set 6 | sola
# Processing Record 29 of Set 6 | port alberni
# Processing Record 30 of Set 6 | mount isa
# Processing Record 31 of Set 6 | laguna
# Processing Record 32 of Set 6 | biak
# Processing Record 33 of Set 6 | quatre cocos
# Processing Record 34 of Set 6 | vylkove
# Processing Record 35 of Set 6 | partizanskoye
# Processing Record 36 of Set 6 | yenagoa
# Processing Record 37 of Set 6 | denau
# City not found. Skipping...
# Processing Record 38 of Set 6 | smithers
# Processing Record 39 of Set 6 | sao joao da barra
# Processing Record 40 of Set 6 | saint george
# Processing Record 41 of Set 6 | gamba
# Processing Record 42 of Set 6 | lindi
# Processing Record 43 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 44 of Set 6 | acapulco
# Processing Record 45 of Set 6 | peniche
# Processing Record 46 of Set 6 | buchanan
# Processing Record 47 of Set 6 | san patricio
# Processing Record 48 of Set 6 | belaya gora
# Processing Record 49 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 6 | nguruka
# Processing Record 1 of Set 7 | cedar city
# Processing Record 2 of Set 7 | casino
# Processing Record 3 of Set 7 | jiuquan
# Processing Record 4 of Set 7 | xapuri
# Processing Record 5 of Set 7 | byron bay
# Processing Record 6 of Set 7 | tomatlan
# Processing Record 7 of Set 7 | johnstown
# Processing Record 8 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 9 of Set 7 | narsaq
# Processing Record 10 of Set 7 | plon
# Processing Record 11 of Set 7 | qaqortoq
# Processing Record 12 of Set 7 | margate
# Processing Record 13 of Set 7 | dwarka
# Processing Record 14 of Set 7 | ancud
# Processing Record 15 of Set 7 | timbiqui
# Processing Record 16 of Set 7 | umm lajj
# Processing Record 17 of Set 7 | hurricane
# Processing Record 18 of Set 7 | avera
# Processing Record 19 of Set 7 | tiznit
# Processing Record 20 of Set 7 | san quintin
# Processing Record 21 of Set 7 | sao jose da coroa grande
# Processing Record 22 of Set 7 | yanchukan
# City not found. Skipping...
# Processing Record 23 of Set 7 | san cristobal
# Processing Record 24 of Set 7 | porto nacional
# Processing Record 25 of Set 7 | pahrump
# Processing Record 26 of Set 7 | kavieng
# Processing Record 27 of Set 7 | kokopo
# Processing Record 28 of Set 7 | port hardy
# Processing Record 29 of Set 7 | panubigan
# Processing Record 30 of Set 7 | zhicheng
# Processing Record 31 of Set 7 | kracheh
# City not found. Skipping...
# Processing Record 32 of Set 7 | tahoua
# Processing Record 33 of Set 7 | lata
# Processing Record 34 of Set 7 | belyy yar
# Processing Record 35 of Set 7 | champoton
# Processing Record 36 of Set 7 | naze
# Processing Record 37 of Set 7 | tabou
# Processing Record 38 of Set 7 | puerto carreno
# Processing Record 39 of Set 7 | maumere
# Processing Record 40 of Set 7 | pangai
# Processing Record 41 of Set 7 | aksu
# Processing Record 42 of Set 7 | leningradskiy
# Processing Record 43 of Set 7 | paranapanema
# Processing Record 44 of Set 7 | zyryanskoye
# Processing Record 45 of Set 7 | luanda
# Processing Record 46 of Set 7 | kaniama
# Processing Record 47 of Set 7 | lensk
# Processing Record 48 of Set 7 | great falls
# Processing Record 49 of Set 7 | bonthe
# Processing Record 50 of Set 7 | zhuhai
# Processing Record 1 of Set 8 | kourou
# Processing Record 2 of Set 8 | omboue
# Processing Record 3 of Set 8 | iqaluit
# Processing Record 4 of Set 8 | santa isabel
# Processing Record 5 of Set 8 | challans
# Processing Record 6 of Set 8 | bushehr
# Processing Record 7 of Set 8 | puerto maldonado
# Processing Record 8 of Set 8 | maniitsoq
# Processing Record 9 of Set 8 | bucerias
# Processing Record 10 of Set 8 | grootfontein
# Processing Record 11 of Set 8 | berlevag
# Processing Record 12 of Set 8 | nagua
# Processing Record 13 of Set 8 | khomeyn
# Processing Record 14 of Set 8 | villazon
# Processing Record 15 of Set 8 | kidal
# Processing Record 16 of Set 8 | bambous virieux
# Processing Record 17 of Set 8 | plessisville
# Processing Record 18 of Set 8 | moose factory
# Processing Record 19 of Set 8 | martapura
# Processing Record 20 of Set 8 | souillac
# Processing Record 21 of Set 8 | luderitz
# Processing Record 22 of Set 8 | mackay
# Processing Record 23 of Set 8 | ocho rios
# Processing Record 24 of Set 8 | svetlogorsk
# Processing Record 25 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 26 of Set 8 | afmadu
# City not found. Skipping...
# Processing Record 27 of Set 8 | changde
# Processing Record 28 of Set 8 | samarai
# Processing Record 29 of Set 8 | riohacha
# Processing Record 30 of Set 8 | praia da vitoria
# Processing Record 31 of Set 8 | ferrol
# Processing Record 32 of Set 8 | yendi
# Processing Record 33 of Set 8 | almeria
# Processing Record 34 of Set 8 | anchorage
# Processing Record 35 of Set 8 | iacu
# Processing Record 36 of Set 8 | katangli
# Processing Record 37 of Set 8 | broken hill
# Processing Record 38 of Set 8 | shimoda
# Processing Record 39 of Set 8 | herat
# Processing Record 40 of Set 8 | lagoa
# Processing Record 41 of Set 8 | kununurra
# Processing Record 42 of Set 8 | hofn
# Processing Record 43 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 8 | noumea
# Processing Record 45 of Set 8 | thanh hoa
# Processing Record 46 of Set 8 | ambon
# Processing Record 47 of Set 8 | la rochelle
# Processing Record 48 of Set 8 | senador guiomard
# Processing Record 49 of Set 8 | linxia
# Processing Record 50 of Set 8 | uyemskiy
# Processing Record 1 of Set 9 | coihaique
# Processing Record 2 of Set 9 | korem
# Processing Record 3 of Set 9 | canico
# Processing Record 4 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 5 of Set 9 | dubbo
# Processing Record 6 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 9 | ghanzi
# Processing Record 8 of Set 9 | kharan
# Processing Record 9 of Set 9 | harwich
# Processing Record 10 of Set 9 | elk city
# Processing Record 11 of Set 9 | ucluelet
# Processing Record 12 of Set 9 | saldanha
# Processing Record 13 of Set 9 | tungor
# Processing Record 14 of Set 9 | aksarka
# Processing Record 15 of Set 9 | moyale
# Processing Record 16 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 9 | las palmas
# Processing Record 18 of Set 9 | dipkarpaz
# City not found. Skipping...
# Processing Record 19 of Set 9 | chiredzi
# Processing Record 20 of Set 9 | tezu
# Processing Record 21 of Set 9 | temaraia
# City not found. Skipping...
# Processing Record 22 of Set 9 | bowen
# Processing Record 23 of Set 9 | kysyl-syr
# Processing Record 24 of Set 9 | cumaribo
# City not found. Skipping...
# Processing Record 25 of Set 9 | maragogi
# Processing Record 26 of Set 9 | guarapari
# Processing Record 27 of Set 9 | alice springs
# Processing Record 28 of Set 9 | jalu
# Processing Record 29 of Set 9 | cavalcante
# Processing Record 30 of Set 9 | mecca
# Processing Record 31 of Set 9 | krasnogvardeyskiy
# Processing Record 32 of Set 9 | marawi
# Processing Record 33 of Set 9 | hovd
# Processing Record 34 of Set 9 | requena
# Processing Record 35 of Set 9 | channel-port aux basques
# Processing Record 36 of Set 9 | flinders
# Processing Record 37 of Set 9 | cockburn harbour
# City not found. Skipping...
# Processing Record 38 of Set 9 | pincher creek
# Processing Record 39 of Set 9 | tromso
# Processing Record 40 of Set 9 | kinkala
# Processing Record 41 of Set 9 | balykshi
# Processing Record 42 of Set 9 | polyarnyye zori
# Processing Record 43 of Set 9 | rawah
# Processing Record 44 of Set 9 | owando
# Processing Record 45 of Set 9 | kiunga
# Processing Record 46 of Set 9 | puerto rico
# Processing Record 47 of Set 9 | murray bridge
# Processing Record 48 of Set 9 | zhanaozen
# Processing Record 49 of Set 9 | ilheus
# Processing Record 50 of Set 9 | antofagasta
# Processing Record 1 of Set 10 | cabedelo
# Processing Record 2 of Set 10 | lavrentiya
# Processing Record 3 of Set 10 | port macquarie
# Processing Record 4 of Set 10 | yeniseysk
# Processing Record 5 of Set 10 | springbok
# Processing Record 6 of Set 10 | champerico
# Processing Record 7 of Set 10 | ascension
# Processing Record 8 of Set 10 | itoigawa
# Processing Record 9 of Set 10 | sucre
# Processing Record 10 of Set 10 | karratha
# Processing Record 11 of Set 10 | eyl
# Processing Record 12 of Set 10 | segou
# Processing Record 13 of Set 10 | januaria
# Processing Record 14 of Set 10 | neryungri
# Processing Record 15 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 16 of Set 10 | ewa beach
# Processing Record 17 of Set 10 | alvdal
# Processing Record 18 of Set 10 | aquidauana
# Processing Record 19 of Set 10 | huarmey
# Processing Record 20 of Set 10 | fort nelson
# Processing Record 21 of Set 10 | tottori
# Processing Record 22 of Set 10 | ganzhou
# Processing Record 23 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 24 of Set 10 | acarau
# Processing Record 25 of Set 10 | sonamura
# Processing Record 26 of Set 10 | turukhansk
# Processing Record 27 of Set 10 | dzilam gonzalez
# Processing Record 28 of Set 10 | mandalgovi
# Processing Record 29 of Set 10 | mayo
# Processing Record 30 of Set 10 | yeppoon
# Processing Record 31 of Set 10 | baft
# Processing Record 32 of Set 10 | pacifica
# Processing Record 33 of Set 10 | polson
# Processing Record 34 of Set 10 | severnoye
# Processing Record 35 of Set 10 | manokwari
# Processing Record 36 of Set 10 | cabinda
# Processing Record 37 of Set 10 | augustow
# Processing Record 38 of Set 10 | hualmay
# Processing Record 39 of Set 10 | cristobal obregon
# Processing Record 40 of Set 10 | taoudenni
# Processing Record 41 of Set 10 | magdagachi
# Processing Record 42 of Set 10 | tual
# Processing Record 43 of Set 10 | coquimbo
# Processing Record 44 of Set 10 | pinsk
# Processing Record 45 of Set 10 | port hawkesbury
# Processing Record 46 of Set 10 | sisophon
# Processing Record 47 of Set 10 | santa cruz
# Processing Record 48 of Set 10 | waipawa
# Processing Record 49 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 50 of Set 10 | fallon
# Processing Record 1 of Set 11 | ibateguara
# Processing Record 2 of Set 11 | yar-sale
# Processing Record 3 of Set 11 | leshan
# Processing Record 4 of Set 11 | sorland
# Processing Record 5 of Set 11 | havre-saint-pierre
# Processing Record 6 of Set 11 | ust-nera
# Processing Record 7 of Set 11 | sasciori
# Processing Record 8 of Set 11 | tchollire
# Processing Record 9 of Set 11 | zyryanovsk
# Processing Record 10 of Set 11 | nemencine
# Processing Record 11 of Set 11 | ust-maya
# Processing Record 12 of Set 11 | goderich
# Processing Record 13 of Set 11 | mildura
# Processing Record 14 of Set 11 | zapolyarnyy
# Processing Record 15 of Set 11 | manggar
# Processing Record 16 of Set 11 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 17 of Set 11 | coolum beach
# Processing Record 18 of Set 11 | turayf
# Processing Record 19 of Set 11 | hami
# Processing Record 20 of Set 11 | nelson bay
# Processing Record 21 of Set 11 | xushan
# Processing Record 22 of Set 11 | lerwick
# Processing Record 23 of Set 11 | huilong
# Processing Record 24 of Set 11 | richards bay
# Processing Record 25 of Set 11 | alekseyevsk
# Processing Record 26 of Set 11 | ha giang
# Processing Record 27 of Set 11 | daru
# Processing Record 28 of Set 11 | gaziantep
# Processing Record 29 of Set 11 | iquique
# Processing Record 30 of Set 11 | simoes
# Processing Record 31 of Set 11 | chapais
# Processing Record 32 of Set 11 | shitanjing
# Processing Record 33 of Set 11 | jiangkou
# Processing Record 34 of Set 11 | hobyo
# Processing Record 35 of Set 11 | northam
# Processing Record 36 of Set 11 | khandyga
# Processing Record 37 of Set 11 | deer lake
# Processing Record 38 of Set 11 | rodrigues alves
# Processing Record 39 of Set 11 | bourail
# Processing Record 40 of Set 11 | saint-joseph
# Processing Record 41 of Set 11 | bathsheba
# Processing Record 42 of Set 11 | ituni
# City not found. Skipping...
# Processing Record 43 of Set 11 | uthal
# Processing Record 44 of Set 11 | shumyachi
# Processing Record 45 of Set 11 | nishihara
# Processing Record 46 of Set 11 | okha
# Processing Record 47 of Set 11 | bethalto
# Processing Record 48 of Set 11 | yanji
# Processing Record 49 of Set 11 | stromness
# Processing Record 50 of Set 11 | west bay
# Processing Record 1 of Set 12 | schoneiche
# Processing Record 2 of Set 12 | presidencia roque saenz pena
# Processing Record 3 of Set 12 | kirakira
# Processing Record 4 of Set 12 | neuquen
# Processing Record 5 of Set 12 | portland
# Processing Record 6 of Set 12 | padang
# Processing Record 7 of Set 12 | libreville
# Processing Record 8 of Set 12 | ouadda
# Processing Record 9 of Set 12 | hirna
# Processing Record 10 of Set 12 | aquin
# Processing Record 11 of Set 12 | zarubino
# Processing Record 12 of Set 12 | djambala
# Processing Record 13 of Set 12 | grand gaube
# Processing Record 14 of Set 12 | atamanovka
# Processing Record 15 of Set 12 | zhangjiakou
# Processing Record 16 of Set 12 | griffith
# Processing Record 17 of Set 12 | reykjavik
# Processing Record 18 of Set 12 | linguere
# Processing Record 19 of Set 12 | moranbah
# Processing Record 20 of Set 12 | kuytun
# Processing Record 21 of Set 12 | deh rawud
# City not found. Skipping...
# Processing Record 22 of Set 12 | borlange
# City not found. Skipping...
# Processing Record 23 of Set 12 | auki
# Processing Record 24 of Set 12 | seoul
# Processing Record 25 of Set 12 | yaqui
# Processing Record 26 of Set 12 | cayenne
# Processing Record 27 of Set 12 | kouroussa
# Processing Record 28 of Set 12 | segezha
# Processing Record 29 of Set 12 | la orilla
# Processing Record 30 of Set 12 | puntarenas
# Processing Record 31 of Set 12 | verkhoturye
# Processing Record 32 of Set 12 | puerto narino
# Processing Record 33 of Set 12 | divnomorskoye
# Processing Record 34 of Set 12 | benguela
# Processing Record 35 of Set 12 | huntingdon
# Processing Record 36 of Set 12 | mezen
# Processing Record 37 of Set 12 | itarema
# Processing Record 38 of Set 12 | dandong
# Processing Record 39 of Set 12 | severo-yeniseyskiy
# Processing Record 40 of Set 12 | garavuti
# Processing Record 41 of Set 12 | normandin
# Processing Record 42 of Set 12 | guapo
# Processing Record 43 of Set 12 | yenangyaung
# Processing Record 44 of Set 12 | tanete
# Processing Record 45 of Set 12 | pervomayskoye
# Processing Record 46 of Set 12 | atar
# Processing Record 47 of Set 12 | okhotsk
# Processing Record 48 of Set 12 | aitape
# Processing Record 49 of Set 12 | yulara
# Processing Record 50 of Set 12 | kargasok
# Processing Record 1 of Set 13 | srednekolymsk
# Processing Record 2 of Set 13 | fare
# Processing Record 3 of Set 13 | dekoa
# City not found. Skipping...
# Processing Record 4 of Set 13 | taltal
# Processing Record 5 of Set 13 | goure
# Processing Record 6 of Set 13 | vikhorevka
# Processing Record 7 of Set 13 | ilo
# Processing Record 8 of Set 13 | port augusta
# Processing Record 9 of Set 13 | juegang
# Processing Record 10 of Set 13 | jablah
# Processing Record 11 of Set 13 | ust-ilimsk
# Processing Record 12 of Set 13 | yaring
# Processing Record 13 of Set 13 | ambilobe
# Processing Record 14 of Set 13 | menongue
# Processing Record 15 of Set 13 | yaan
# Processing Record 16 of Set 13 | knysna
# Processing Record 17 of Set 13 | bandarbeyla
# Processing Record 18 of Set 13 | hangu
# Processing Record 19 of Set 13 | leh
# Processing Record 20 of Set 13 | outjo
# Processing Record 21 of Set 13 | tigil
# Processing Record 22 of Set 13 | mana
# Processing Record 23 of Set 13 | berdigestyakh
# Processing Record 24 of Set 13 | mweka
# Processing Record 25 of Set 13 | elat
# Processing Record 26 of Set 13 | swellendam
# Processing Record 27 of Set 13 | bilibino
# Processing Record 28 of Set 13 | mwingi
# Processing Record 29 of Set 13 | soyo
# Processing Record 30 of Set 13 | lincoln
# Processing Record 31 of Set 13 | ploemeur
# Processing Record 32 of Set 13 | touros
# Processing Record 33 of Set 13 | rundu
# Processing Record 34 of Set 13 | harper
# Processing Record 35 of Set 13 | sabalgarh
# Processing Record 36 of Set 13 | grindavik
# Processing Record 37 of Set 13 | arakhova
# City not found. Skipping...
# Processing Record 38 of Set 13 | daliang
# Processing Record 39 of Set 13 | vostok
# Processing Record 40 of Set 13 | girua
# Processing Record 41 of Set 13 | krasnoselkup
# Processing Record 42 of Set 13 | teluknaga
# Processing Record 43 of Set 13 | oranjestad
# Processing Record 44 of Set 13 | colares
# Processing Record 45 of Set 13 | nova olimpia
# Processing Record 46 of Set 13 | arys
# Processing Record 47 of Set 13 | suzu
# City not found. Skipping...
# Processing Record 48 of Set 13 | beringovskiy
# Processing Record 49 of Set 13 | columbus
# Processing Record 50 of Set 13 | pacific grove
# Processing Record 1 of Set 14 | tawkar
# City not found. Skipping...
# Processing Record 2 of Set 14 | ocampo
# Processing Record 3 of Set 14 | hokitika
# Processing Record 4 of Set 14 | pemba
# Processing Record 5 of Set 14 | lakes entrance
# Processing Record 6 of Set 14 | kamenka
# Processing Record 7 of Set 14 | beruni
# City not found. Skipping...
# Processing Record 8 of Set 14 | pauini
# Processing Record 9 of Set 14 | saint-pierre
# Processing Record 10 of Set 14 | tevriz
# Processing Record 11 of Set 14 | lircay
# Processing Record 12 of Set 14 | espirito santo do pinhal
# Processing Record 13 of Set 14 | chulym
# Processing Record 14 of Set 14 | mullaitivu
# City not found. Skipping...
# Processing Record 15 of Set 14 | altamont
# Processing Record 16 of Set 14 | wattegama
# Processing Record 17 of Set 14 | port-cartier
# Processing Record 18 of Set 14 | kralendijk
# Processing Record 19 of Set 14 | mogadishu
# Processing Record 20 of Set 14 | whitehorse
# Processing Record 21 of Set 14 | asayita
# City not found. Skipping...
# Processing Record 22 of Set 14 | chateaubelair
# Processing Record 23 of Set 14 | bambanglipuro
# Processing Record 24 of Set 14 | kalutara
# Processing Record 25 of Set 14 | ahuimanu
# Processing Record 26 of Set 14 | shache
# Processing Record 27 of Set 14 | ankpa
# Processing Record 28 of Set 14 | velika kladusa
# Processing Record 29 of Set 14 | ye
# City not found. Skipping...
# Processing Record 30 of Set 14 | namtsy
# Processing Record 31 of Set 14 | yarim
# Processing Record 32 of Set 14 | grand-santi
# Processing Record 33 of Set 14 | nantucket
# Processing Record 34 of Set 14 | stolac
# Processing Record 35 of Set 14 | acari
# Processing Record 36 of Set 14 | qingquan
# Processing Record 37 of Set 14 | north bend
# Processing Record 38 of Set 14 | banjar
# Processing Record 39 of Set 14 | kawanoe
# Processing Record 40 of Set 14 | sirjan
# Processing Record 41 of Set 14 | monrovia
# Processing Record 42 of Set 14 | flin flon
# Processing Record 43 of Set 14 | kibondo
# Processing Record 44 of Set 14 | sioux lookout
# Processing Record 45 of Set 14 | san andres
# Processing Record 46 of Set 14 | chitipa
# Processing Record 47 of Set 14 | tidore
# City not found. Skipping...
# Processing Record 48 of Set 14 | duncan
# Processing Record 49 of Set 14 | wanning
# Processing Record 50 of Set 14 | skibbereen
# Processing Record 1 of Set 15 | mizdah
# Processing Record 2 of Set 15 | akureyri
# Processing Record 3 of Set 15 | kuching
# Processing Record 4 of Set 15 | sol-iletsk
# Processing Record 5 of Set 15 | mwinilunga
# Processing Record 6 of Set 15 | karimnagar
# Processing Record 7 of Set 15 | stamsund
# City not found. Skipping...
# Processing Record 8 of Set 15 | merauke
# Processing Record 9 of Set 15 | college
# Processing Record 10 of Set 15 | monte carmelo
# Processing Record 11 of Set 15 | banmo
# City not found. Skipping...
# Processing Record 12 of Set 15 | lisala
# Processing Record 13 of Set 15 | banda aceh
# Processing Record 14 of Set 15 | arlit
# Processing Record 15 of Set 15 | boca do acre
# Processing Record 16 of Set 15 | bonavista
# Processing Record 17 of Set 15 | rio grande
# Processing Record 18 of Set 15 | teknaf
# Processing Record 19 of Set 15 | nyirtelek
# Processing Record 20 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 21 of Set 15 | pilot butte
# Processing Record 22 of Set 15 | kedougou
# Processing Record 23 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 24 of Set 15 | dianopolis
# City not found. Skipping...
# Processing Record 25 of Set 15 | sistranda
# Processing Record 26 of Set 15 | high prairie
# Processing Record 27 of Set 15 | albina
# Processing Record 28 of Set 15 | erenhot
# Processing Record 29 of Set 15 | humaita
# Processing Record 30 of Set 15 | jinchang
# Processing Record 31 of Set 15 | broome
# Processing Record 32 of Set 15 | prince rupert
# Processing Record 33 of Set 15 | gurskoye
# City not found. Skipping...
# Processing Record 34 of Set 15 | marzuq
# Processing Record 35 of Set 15 | opuwo
# Processing Record 36 of Set 15 | buraydah
# Processing Record 37 of Set 15 | uusikaupunki
# Processing Record 38 of Set 15 | vitre
# Processing Record 39 of Set 15 | amapa
# Processing Record 40 of Set 15 | lompoc
# Processing Record 41 of Set 15 | balsas
# Processing Record 42 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 43 of Set 15 | cassilandia
# Processing Record 44 of Set 15 | nanchang
# Processing Record 45 of Set 15 | qunduz
# Processing Record 46 of Set 15 | the pas
# Processing Record 47 of Set 15 | salacgriva
# Processing Record 48 of Set 15 | redcliffe
# Processing Record 49 of Set 15 | sao jose do belmonte
# Processing Record 50 of Set 15 | camacha
# Processing Record 1 of Set 16 | puerto penasco
# Processing Record 2 of Set 16 | siparia
# Processing Record 3 of Set 16 | sonqor
# Processing Record 4 of Set 16 | kazalinsk
# City not found. Skipping...
# Processing Record 5 of Set 16 | kaeo
# Processing Record 6 of Set 16 | kapuskasing
# Processing Record 7 of Set 16 | thinadhoo
# Processing Record 8 of Set 16 | san francisco
# Processing Record 9 of Set 16 | labuhan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 703

# %%
# Create a DataFrame of City Weather Data
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Esperance -33.8667  121.9000     78.64        70           0
# 1        Isangel -19.5500  169.2667     79.50        81           0
# 2          Pisco -13.7000  -76.2167     66.25        82           0
# 3   Punta Arenas -53.1500  -70.9167     50.11        93           0
# 4   Port Lincoln -34.7333  135.8667     61.43        69          19
# 5        Ushuaia -54.8000  -68.3000     49.66        71          75
# 6      Carnarvon -24.8667  113.6333     80.67        69           7
# 7         Kodiak  57.7900 -152.4072     37.72        73         100
# 8          Vardo  70.3705   31.1107     26.56        86         100
# 9  Pangkalanbuun  -2.6833  111.6167     82.13        79          95
#
#    Wind Speed Current Description Country
# 0       26.82           clear sky      AU
# 1        4.12           clear sky      VU
# 2        5.75           clear sky      PE
# 3       11.50           clear sky      CL
# 4       20.96          few clouds      AU
# 5       13.80       broken clouds      AR
# 6       24.16           clear sky      AU
# 7        3.69     overcast clouds      US
# 8       18.03          light snow      NO
# 9        5.82       moderate rain      ID

# %%
# new column order
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Esperance      AU -33.8667  121.9000     78.64        70           0
# 1        Isangel      VU -19.5500  169.2667     79.50        81           0
# 2          Pisco      PE -13.7000  -76.2167     66.25        82           0
# 3   Punta Arenas      CL -53.1500  -70.9167     50.11        93           0
# 4   Port Lincoln      AU -34.7333  135.8667     61.43        69          19
# 5        Ushuaia      AR -54.8000  -68.3000     49.66        71          75
# 6      Carnarvon      AU -24.8667  113.6333     80.67        69           7
# 7         Kodiak      US  57.7900 -152.4072     37.72        73         100
# 8          Vardo      NO  70.3705   31.1107     26.56        86         100
# 9  Pangkalanbuun      ID  -2.6833  111.6167     82.13        79          95
#
#    Wind Speed Current Description
# 0       26.82           clear sky
# 1        4.12           clear sky
# 2        5.75           clear sky
# 3       11.50           clear sky
# 4       20.96          few clouds
# 5       13.80       broken clouds
# 6       24.16           clear sky
# 7        3.69     overcast clouds
# 8       18.03          light snow
# 9        5.82       moderate rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
